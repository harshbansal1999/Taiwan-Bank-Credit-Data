# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel('TaiwanCreditDefaults.xls',header=1)

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID                            30000 non-null int64
# LIMIT_BAL                     30000 non-null int64
# SEX                           30000 non-null int64
# EDUCATION                     30000 non-null int64
# MARRIAGE                      30000 non-null int64
# AGE                           30000 non-null int64
# PAY_0                         30000 non-null int64
# PAY_2                         30000 non-null int64
# PAY_3                         30000 non-null int64
# PAY_4                         30000 non-null int64
# PAY_5                         30000 non-null int64
# PAY_6                         30000 non-null int64
# BILL_AMT1                     30000 non-null int64
# BILL_AMT2                     30000 non-null int64
# BILL_AMT3                     30000 non-null int64
# BILL_AMT4                     30000 non-null int64
# ...

# %%
df.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
df.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
df['default payment next month'].value_counts()
# Out:
# 0    23364
# 1     6636
# Name: default payment next month, dtype: int64

# %%
sns.countplot(df['default payment next month'])

# %%
sns.countplot(df['SEX'])

# %%
sns.countplot(df['default payment next month'],hue=df['SEX'])

# %%
sns.countplot(df['default payment next month'],hue=df['MARRIAGE'])

# %%
fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(13.7, 10.27)
sns.barplot(df['AGE'],df['LIMIT_BAL'])

# %%
sns.distplot(np.log(df['LIMIT_BAL']),bins=100)

# %%
sns.distplot(df['LIMIT_BAL'],bins=100)

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
data=df
#Outliers Detection
mean,std=np.mean(data['LIMIT_BAL']),np.std(data['LIMIT_BAL'])
z_score=np.abs((data['LIMIT_BAL']-mean)/std)
threshold=3
good=z_score<threshold
print(f'Rejection: {(~good).sum()} points')

from scipy.stats import norm
print(f"z_score of 5 corresponds to prob of {100*2*norm.sf(threshold):0.2f}%")
visual_scatter=np.random.normal(size=data['LIMIT_BAL'].size)

plt.figure(figsize=(10,5))
plt.scatter(data['LIMIT_BAL'][good],visual_scatter[good],s=2,label='Good',color='#4CAF50')
plt.scatter(data['LIMIT_BAL'][~good],visual_scatter[~good],s=2,label='BAD',color='#F44336')
plt.legend()
# Out:
# Rejection: 130 points
# z_score of 5 corresponds to prob of 0.27%

# %%
df=df[df['LIMIT_BAL']<500000]

# %%
df.loc[:,['LIMIT_BAL','SEX']].groupby('SEX').mean().plot(kind='bar')

# %%
df.loc[:,['LIMIT_BAL','EDUCATION']].groupby('EDUCATION').mean().plot(kind='bar')

# %%
df.loc[:,['LIMIT_BAL','MARRIAGE']].groupby('MARRIAGE').mean().plot(kind='bar')

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot=True)

# %%
train=df.drop('default payment next month',axis=1)
test=df['default payment next month']

# %%
train.corrwith(test).plot.bar(figsize=(20,10),
                                           title="Correalation with response variable",
                                           fontsize=15,rot=45,grid=True)

# %%
train_new=train.drop(['ID','MARRIAGE','AGE','BILL_AMT1','BILL_AMT2','BILL_AMT3','BILL_AMT4','BILL_AMT5'],axis=1)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
train=sc.fit_transform(train)
train_new=sc.fit_transform(train_new)

# %%
test=np.array(test)

# %%
train.shape,test.shape
# Out:
# ((29072, 24), (29072,))

# %%
tr=train[:1000,]
te=test[:1000,]

# %%
from sklearn import model_selection
x_train,x_test,y_train,y_test=model_selection.train_test_split(train,test)

# %%
#Applying Oversampling
#Handling the Imbalanced data - SMOTE (Synthetic Minority Over-sampling Technique)
from imblearn.over_sampling import SMOTE
sm=SMOTE(random_state=12)
X_res,y_res=sm.fit_sample(x_train,y_train)

# %%
unique,count=np.unique(y_res,return_counts=True)
y_smote_value_count={k:v for (k,v) in zip(unique,count)}
y_smote_value_count
# Out:
# {0: 16917, 1: 16917}

# %%
x_train_1,x_test_1,y_train_1,y_test_1=model_selection.train_test_split(tr,te)

# %%
#Applying Oversampling
#Handling the Imbalanced data - SMOTE (Synthetic Minority Over-sampling Technique)
from imblearn.over_sampling import SMOTE
sm=SMOTE(random_state=12)
x_res_1,y_res_1=sm.fit_sample(x_train_1,y_train_1)

# %%
unique,count=np.unique(y_res_1,return_counts=True)
y_smote_value_count={k:v for (k,v) in zip(unique,count)}
y_smote_value_count
# Out:
# {0: 598, 1: 598}

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix,classification_report

# %%
from tpot import TPOTClassifier
from sklearn.metrics import roc_auc_score

# %%
tpot = TPOTClassifier(
    generations=5,
    population_size=20,
    verbosity=2,
    scoring='roc_auc',
    random_state=42,
    disable_update_check=True,
    config_dict='TPOT light'
)
tpot.fit(x_res_1, y_res_1)
# Out:
# ...
# Generation 1 - Current best internal CV score: 0.8825981559290381
# Generation 2 - Current best internal CV score: 0.9243096988795518
# Generation 3 - Current best internal CV score: 0.9243096988795518
# Generation 4 - Current best internal CV score: 0.9243096988795518
# Generation 5 - Current best internal CV score: 0.9243096988795518
#
# Best pipeline: KNeighborsClassifier(input_matrix, n_neighbors=3, p=1, weights=distance)
# TPOTClassifier(config_dict='TPOT light', crossover_rate=0.1, cv=5,
#                disable_update_check=True, early_stop=None, generations=5,
#                max_eval_time_mins=5, max_time_mins=None, memory=None,
#                mutation_rate=0.9, n_jobs=1, offspring_size=None,
#                periodic_checkpoint_folder=None, population_size=20,
#                random_state=42, scoring='roc_auc', subsample=1.0, template=None,
#                use_dask=False, verbosity=2, warm_start=False)

# %%
tpot_auc_score = roc_auc_score(y_test, tpot.predict_proba(x_test)[:, 1])
print(f'\nAUC score: {tpot_auc_score:.4f}')
# Out:
# AUC score: 0.6291

# %%
print('\nBest pipeline steps:', end='\n')
for idx, (name, transform) in enumerate(tpot.fitted_pipeline_.steps, start=1):
    print(f'{idx}. {transform}')
# Out:
# Best pipeline steps:
# 1. KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=1,
#                      weights='distance')

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
                     metric_params=None, n_jobs=None, n_neighbors=3, p=1,
                     weights='distance')
neigh.fit(X_res, y_res)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=1,
#                      weights='distance')

# %%
y_pred=neigh.predict(x_test)
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.84      0.78      4845
#            1       0.52      0.35      0.42      2423
#
#     accuracy                           0.68      7268
#    macro avg       0.62      0.60      0.60      7268
# weighted avg       0.66      0.68      0.66      7268

# %% [markdown]
# # Random Forest

# %%
alg1=RandomForestClassifier()

# %%
alg1
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
params={'max_depth':[3,4,5,6,8,9,10],
        'n_estimators':[100,150,200,250,400,500,700,800,900,1000,1050],
        'criterion':['gini','entropy']
       }
grid_model=GridSearchCV(estimator=alg1,param_grid=params,n_jobs=-1,cv=5,return_train_score=True,scoring='roc_auc')
grid_model.fit(x_res_1,y_res_1)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=100, n_jobs=None,
#                                               oob_score=False,
# ...

# %%
grid_model.best_score_
# Out:
# 0.9340950046685341

# %%
grid_model.best_estimator_
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=10, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=900,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
alg1=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
                       criterion='gini', max_depth=10, max_features='auto',
                       max_leaf_nodes=None, max_samples=None,
                       min_impurity_decrease=0.0, min_impurity_split=None,
                       min_samples_leaf=1, min_samples_split=2,
                       min_weight_fraction_leaf=0.0, n_estimators=900,
                       n_jobs=None, oob_score=False, random_state=None,
                       verbose=0, warm_start=False)
alg1.fit(X_res,y_res)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=10, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=900,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
cv=cross_val_score(alg1,X_res,y_res,scoring='roc_auc',cv=5,n_jobs=-1)
cv.mean()
# Out:
# 0.8555324861611039

# %%
y_pred1=alg1.predict(x_test)

# %%
print(classification_report(y_pred1,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.87      0.86      5525
#            1       0.57      0.53      0.55      1743
#
#     accuracy                           0.79      7268
#    macro avg       0.71      0.70      0.71      7268
# weighted avg       0.79      0.79      0.79      7268

# %%
acc=(cm[0,0]+cm[1,1])/(cm[0,0]+cm[1,1]+cm[0,1]+cm[1,0])
acc
# Out:
# 0.7937534397358282
